# %%
import xlrd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
project_df = pd.read_excel('Project_File.xlsx')
print(project_df)
# Out:
#                   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# 1             5948       653                    1672           4834
# 2             6107       820                    2152           5642
# 3             5805       690                    1598           5993
# 4             5542       524                    1449           5038
# ..             ...       ...                     ...            ...
# 114          10462      1053                    4055          10967
# 115          10254      1555                    3249           8432
# 116           6902      1002                    2500           7272
# 117           7147       841                    2425           9833
# 118           7384      1001                    2454           9023
#
#       Austria    Scandinavia    CIS & Eastern Europe
# 0         1354          11653                   15177
# 1         1380          11452                    8952
# 2         1495          12522                    9822
# 3         1220           7492                    8431
# 4         1027           5358                    8536
# ..         ...            ...                     ...
# 114       2782          12177                   13383
# 115       3027           6468                   13499
# 116       2251           6099                   12541
# 117       2011           9228                   15079
# 118       2634           9675                   18423
#
# [119 rows x 12 columns]

# %%
project_df.dropna()
# Out:
#                   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# 1             5948       653                    1672           4834
# 2             6107       820                    2152           5642
# 3             5805       690                    1598           5993
# 4             5542       524                    1449           5038
# ..             ...       ...                     ...            ...
# 114          10462      1053                    4055          10967
# 115          10254      1555                    3249           8432
# 116           6902      1002                    2500           7272
# 117           7147       841                    2425           9833
# 118           7384      1001                    2454           9023
#
#       Austria    Scandinavia    CIS & Eastern Europe
# 0         1354          11653                   15177
# 1         1380          11452                    8952
# 2         1495          12522                    9822
# 3         1220           7492                    8431
# 4         1027           5358                    8536
# ..         ...            ...                     ...
# 114       2782          12177                   13383
# 115       3027           6468                   13499
# 116       2251           6099                   12541
# 117       2011           9228                   15079
# 118       2634           9675                   18423
#
# [119 rows x 12 columns]

# %%
print(project_df)
# Out:
#                   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# 1             5948       653                    1672           4834
# 2             6107       820                    2152           5642
# 3             5805       690                    1598           5993
# 4             5542       524                    1449           5038
# ..             ...       ...                     ...            ...
# 114          10462      1053                    4055          10967
# 115          10254      1555                    3249           8432
# 116           6902      1002                    2500           7272
# 117           7147       841                    2425           9833
# 118           7384      1001                    2454           9023
#
#       Austria    Scandinavia    CIS & Eastern Europe
# 0         1354          11653                   15177
# 1         1380          11452                    8952
# 2         1495          12522                    9822
# 3         1220           7492                    8431
# 4         1027           5358                    8536
# ..         ...            ...                     ...
# 114       2782          12177                   13383
# 115       3027           6468                   13499
# 116       2251           6099                   12541
# 117       2011           9228                   15079
# 118       2634           9675                   18423
#
# [119 rows x 12 columns]

# %%
project_df.columns = ['Year', 'United Kingdom', 'Germany', 'France', 'Italy', 'Netherlands', 'Greece', 'Belgium & Luxembourg', 'Switzerland', 'Austria', 'Scandinavia', 'CIS & Eastern Europe']
print(project_df)
# Out:
#            Year  United Kingdom  Germany  France  Italy  Netherlands  Greece  \
# 0     2008 Jan            47607    14269    8771   3719         5988     720
# 1     2008 Feb            51178    15670    9093   3226         5948     653
# 2     2008 Mar            61263    18467    9707   3420         6107     820
# 3     2008 Apr            41645    14169    9897   3556         5805     690
# 4     2008 May            29785    11609    8451   2638         5542     524
# ..          ...             ...      ...     ...    ...          ...     ...
# 114   2017 Jul            38408    21206   18255   6984        10462    1053
# 115   2017 Aug            43459    26590   23815  19114        10254    1555
# 116   2017 Sep            42416    24858   11584   6568         6902    1002
# 117   2017 Oct            41912    27617   14082   5280         7147     841
# 118   2017 Nov            45111    28379   14207   6424         7384    1001
#
#      Belgium & Luxembourg  Switzerland  Austria  Scandinavia  \
# 0                    1574         4884     1354        11653
# 1                    1672         4834     1380        11452
# 2                    2152         5642     1495        12522
# 3                    1598         5993     1220         7492
# 4                    1449         5038     1027         5358
# ..                    ...          ...      ...          ...
# 114                  4055        10967     2782        12177
# 115                  3249         8432     3027         6468
# 116                  2500         7272     2251         6099
# 117                  2425         9833     2011         9228
# 118                  2454         9023     2634         9675
#
#      CIS & Eastern Europe
# 0                   15177
# 1                    8952
# 2                    9822
# 3                    8431
# 4                    8536
# ..                    ...
# 114                 13383
# 115                 13499
# 116                 12541
# 117                 15079
# 118                 18423
#
# [119 rows x 12 columns]

# %%
sns.histplot(data=project_df, x="Germany", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="France", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="United Kingdom", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="Italy", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="Netherlands", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="Greece", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="Belgium & Luxembourg", bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=project_df, x="Switzerland", bins=10)
plt.show

# %%
sns.histplot(data=project_df, x="Austria", bins=10)
plt.show

# %%
sns.histplot(data=project_df, x="Scandinavia", bins=10)
plt.show

# %%
sns.histplot(data=project_df, x="CIS & Eastern Europe", bins=10)
plt.show

# %%
References : https://dev.to/thalesbruno/subplotting-with-matplotlib-and-seaborn-5ei8

# %%
# later have time then troubleshoot. 
plt.hist(project_df, bins=20,
         alpha = 0.8 , rwidth = 1.00)
plt.figure(figsize=(30,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bar =sns.barplot(data=project_df, x= "Germany", y= "Year")
#bar.set_ylim(range(0, 75))
#bar.set_xticks(range(1,100))
plt.show()

# %%
#chart01= sns.barplot(data=project_df, x="Year", y="Germany")
#chart01.set_xlim(range(0,200))
#plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

x = np.linspace(-15, 15, 100)
y = np.sin(x)

plt.plot(x, y)

plt.xlim(-10, 10)
plt.ylim(-1, 1)

plt.show()
