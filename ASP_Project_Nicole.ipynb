# %%
import xlrd
import pandas as pd
import numpy as np

# %%
project_df = pd.read_excel('Project_File.xlsx')
print(project_df)
# Out:
#                   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# ...

# %%
project_df.dropna()
# Out:
#            Year   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# ...

# %%
col = list(project_df.columns)
col[0] = "Year"

print(col)
# Out:
# ['Year', ' United Kingdom ', ' Germany ', ' France ', ' Italy ', ' Netherlands ', ' Greece ', ' Belgium & Luxembourg ', ' Switzerland ', ' Austria ', ' Scandinavia ', ' CIS & Eastern Europe ']

# %%
project_df.columns = col


print(project_df)
# Out:
#            Year   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# ...

# %%
project_df.columns =
print(project_df)
# Out:
#            Year   United Kingdom    Germany    France    Italy   \
# 0     2008 Jan              47607      14269      8771     3719
# 1     2008 Feb              51178      15670      9093     3226
# 2     2008 Mar              61263      18467      9707     3420
# 3     2008 Apr              41645      14169      9897     3556
# 4     2008 May              29785      11609      8451     2638
# ..          ...               ...        ...       ...      ...
# 114   2017 Jul              38408      21206     18255     6984
# 115   2017 Aug              43459      26590     23815    19114
# 116   2017 Sep              42416      24858     11584     6568
# 117   2017 Oct              41912      27617     14082     5280
# 118   2017 Nov              45111      28379     14207     6424
#
#       Netherlands    Greece    Belgium & Luxembourg    Switzerland   \
# 0             5988       720                    1574           4884
# ...

# %%
print(project_df.dtypes)
# Out:
# Year                      object
#  United Kingdom            int64
#  Germany                   int64
#  France                    int64
#  Italy                     int64
#  Netherlands               int64
#  Greece                    int64
#  Belgium & Luxembourg      int64
#  Switzerland               int64
#  Austria                   int64
#  Scandinavia               int64
#  CIS & Eastern Europe      int64
# Europe                    object
# dtype: object

# %%
project_df.head(10)
# Out:
#          Year   United Kingdom    Germany    France    Italy    Netherlands   \
# 0   2008 Jan              47607      14269      8771     3719           5988
# 1   2008 Feb              51178      15670      9093     3226           5948
# 2   2008 Mar              61263      18467      9707     3420           6107
# 3   2008 Apr              41645      14169      9897     3556           5805
# 4   2008 May              29785      11609      8451     2638           5542
# 5   2008 Jun              27578      10893      7147     2450           4945
# 6   2008 Jul              33476      13500     11267     3971           7759
# 7   2008 Aug              39090      14690     13597     6556           7241
# 8   2008 Sep              34246      14033      7682     3397           5476
# 9   2008 Oct              39720      16762      8200     3077           6525
#
#     Greece    Belgium & Luxembourg    Switzerland    Austria    Scandinavia   \
# ...

# %%
project_df["Germany"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda.og\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda.og\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda.og\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Germany'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
project_df['United Kingdom']=project_df['United Kingdom'].astype('float64')
project_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda.og\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda.og\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda.og\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'United Kingdom'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
newdata = project_df["col1"]

# %%
df1 = pd.Series(project_df)
print(df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df1 = pd.Series(project_df)
#       2 print(df1)
#
# File ~\anaconda.og\lib\site-packages\pandas\core\series.py:367, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     363 else:
#     365     name = ibase.maybe_extract_name(name, data, type(self))
# --> 367     if is_empty_data(data) and dtype is None:
#     368         # gh-17261
#     369         warnings.warn(
#     370             "The default dtype for empty Series will be 'object' instead "
#     371             "of 'float64' in a future version. Specify a dtype explicitly "
#    (...)
#     374             stacklevel=find_stack_level(),
#     375         )
#     376         # uncomment the line below when removing the FutureWarning
#     377         # dtype = np.dtype(object)
#
# ...

# %%
df = pd.to_numeric(project_df, errors='coerce')
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df = pd.to_numeric(project_df, errors='coerce')
#       2 print(df)
#
# File ~\anaconda.og\lib\site-packages\pandas\core\tools\numeric.py:164, in to_numeric(arg, errors, downcast)
#     162     values = np.array([arg], dtype="O")
#     163 elif getattr(arg, "ndim", 1) > 1:
# --> 164     raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     165 else:
#     166     values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
project_df['Year']

# %%
ax = project_df['Year'].plot(kind='hist', title="Region over span of 10 years", figsize=(10,10), legend=True, fontsize=12)

print(ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 ax = project_df['Year'].plot(kind='hist', title="Region over span of 10 years", figsize=(10,10), legend=True, fontsize=12)
#       3 print(ax)
#
# File ~\anaconda.og\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda.og\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
project_df.head(10)
# Out:
#          Year   United Kingdom    Germany    France    Italy    Netherlands   \
# 0   2008 Jan              47607      14269      8771     3719           5988
# 1   2008 Feb              51178      15670      9093     3226           5948
# 2   2008 Mar              61263      18467      9707     3420           6107
# 3   2008 Apr              41645      14169      9897     3556           5805
# 4   2008 May              29785      11609      8451     2638           5542
# 5   2008 Jun              27578      10893      7147     2450           4945
# 6   2008 Jul              33476      13500     11267     3971           7759
# 7   2008 Aug              39090      14690     13597     6556           7241
# 8   2008 Sep              34246      14033      7682     3397           5476
# 9   2008 Oct              39720      16762      8200     3077           6525
#
#     Greece    Belgium & Luxembourg    Switzerland    Austria    Scandinavia   \
# ...
